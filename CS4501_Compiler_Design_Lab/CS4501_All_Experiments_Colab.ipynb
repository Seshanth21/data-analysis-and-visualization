# %% [markdown]
# # CS4501 Compiler Design - All 10 Experiments
#
# This notebook installs GNU Flex/Bison, downloads the GitHub branch, executes every program, verifies the output, and packages the results.

# %%
# !apt-get -qq update
# !apt-get -qq install -y flex bison gcc
# !flex --version
# !bison --version | head -n 1

# %%
# !rm -rf /content/data-analysis-and-visualization
# !git clone --depth 1 --branch cs4501-compiler-design-lab https://github.com/Seshanth21/data-analysis-and-visualization.git /content/data-analysis-and-visualization
# %cd /content/data-analysis-and-visualization/CS4501_Compiler_Design_Lab

# %%
# !bash scripts/run_all.sh

# %%
from pathlib import Path
for output in sorted(Path('outputs').glob('experiment_*.txt')):
    print('\n' + '=' * 88)
    print(output.name)
    print('=' * 88)
    print(output.read_text())

# %%
# !zip -qr /content/CS4501_Compiler_Design_Executed_Outputs.zip outputs reports experiments scripts README.md SOURCE_ALIGNMENT.md Makefile
from google.colab import files
files.download('/content/CS4501_Compiler_Design_Executed_Outputs.zip')
